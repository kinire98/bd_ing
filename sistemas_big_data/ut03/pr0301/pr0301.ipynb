# %% [markdown]
# # PR0301: Ingesta de datos de archivos

# %% [markdown]
# ## Ingesta CSV

# %%
import pandas as pd

df = pd.read_csv("./ventas_norte.csv", sep=";", dtype={"Cantidad_Vendida": int, "Precio_Unit": int, "Nom_Producto": str}, parse_dates=["Fecha_Venta"], index_col="ID_Transaccion")
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv("./ventas_norte.csv", sep=";", dtype={"Cantidad_Vendida": int, "Precio_Unit": int, "Nom_Producto": str}, parse_dates=["Fecha_Venta"], index_col="ID_Transaccion")
#       4 df
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 1000 to 1099
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fecha_Venta       100 non-null    datetime64[ns]
#  1   Nom_Producto      100 non-null    object
#  2   Cantidad_Vendida  100 non-null    int64
#  3   Precio_Unit       100 non-null    int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 3.9+ KB

# %% [markdown]
# ## Ingesta Excel

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /usr/bin/python
# 3.13.11 (main, Dec  7 2025, 13:01:45) [GCC 15.2.1 20251112]

# %%
df_sur = pd.read_excel("./ventas_sur.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /usr/lib/python3.13/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /usr/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...
